# %% [markdown]
# # Cap 02 - Programando uma Tartaruga em Python

# %%
from ColabTurtle.Turtle import *

initializeTurtle()

forward(150)
left(90)
forward(75)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="100.0" x2="325.0" y2="100.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(270,325.0,100.0) translate(307.0, 82.0)">
# ...

# %%
from ColabTurtle.Turtle import *

initializeTurtle(initial_speed=5)

bgcolor ("lightgreen")
color ("blue")
pensize (3)

forward(50)
left(120)
forward(50)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="hotpink"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:blue;stroke-width:3"/><line x1="400.0" y1="200.0" x2="356.699" y2="225.0" stroke-linecap="round" style="stroke:blue;stroke-width:3"/><line x1="356.699" y1="225.0" x2="313.398" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:5"/><line x1="313.398" y1="250.0" x2="356.699" y2="275.0" stroke-linecap="round" style="stroke:blue;stroke-width:5"/>
#         <g visibility=visible transform="rotate(120,356.699,275.0) translate(338.699, 257.0)">
# ...

# %%
from ColabTurtle. Turtle import *
cor_fundo = input ("Digite a cor do de fundo (ex: lightgreen, hotpink, peachpuff):")
cor_tartaruga = input("Digite a cor da tartaruga (ex.: blue, red, purple):")
espessura = int(input("Digite a espessura da caneta (ex.: 1, 3, 5)"))

bgcolor(cor_fundo)
color(cor_tartaruga)
pensize(espessura)

forward(50)
left(120)
forward(50)

# %%
from ColabTurtle.Turtle import *

initializeTurtle(initial_speed=5)

bgcolor ("lightgreen")

# tess desenha um triangulo equilatero

color("hotpink")
pensize(5)
forward(80)
left(120)
forward(80)
left(120)
right(180)
forward(80)

# alex desenha um quadrado

color ("blue")
pensize(1)
forward(50)
left(90)
forward(50)
left(90)
forward(50)
left(90)
forward(50)
left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="lightgreen"/>
#         <line x1="400" y1="250" x2="400.0" y2="170.0" stroke-linecap="round" style="stroke:hotpink;stroke-width:5"/><line x1="400.0" y1="170.0" x2="330.718" y2="210.0" stroke-linecap="round" style="stroke:hotpink;stroke-width:5"/><line x1="330.718" y1="210.0" x2="261.436" y2="170.0" stroke-linecap="round" style="stroke:hotpink;stroke-width:5"/><line x1="261.436" y1="170.0" x2="218.135" y2="145.0" stroke-linecap="round" style="stroke:blue;stroke-width:1"/><line x1="218.135" y1="145.0" x2="193.135" y2="188.301" stroke-linecap="round" style="stroke:blue;stroke-width:1"/><line x1="193.135" y1="188.301" x2="236.436" y2="213.301" stroke-linecap="round" style="stroke:blue;stroke-width:1"/><line x1="236.436" y1="213.301" x2="261.436" y2="170.0" stroke-linecap="round" style="stroke:blue;stroke-width:1"/>
# ...
