# %%
print(1+2)
# Out:
# 3

# %%
print("meu primeiro programa som os numeros e e 3:")
print(2+3)
# Out:
# meu primeiro programa som os numeros e e 3:
# 5

# %%
print ("ola mundo!")
# Out:
# ola mundo!

# %%
print(type("ola, mundo!"))
print(type(17))
print("ola, mundo")
# Out:
# <class 'str'>
# <class 'int'>
# ola, mundo

# %%
print(type(3.2))
# Out:
# <class 'float'>

# %%
print(type("17"))
print(type("3.2"))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(type("esse é um string,"))
print(type('e esse tambem é uma estring'))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(' " oh nao", exclamou ela, "a bicicleta está quebrada!"  ')
# Out:
#  " oh nao", exclamou ela, "a bicicleta está quebrada!"

# %%
mensagem = """ esta mensagem ira 
se estender por varias 
linhas. """
print(mensagem)

print("""esta mensagem se estende
por varias linhas
do texto.""")
# Out:
#  esta mensagem ira
# se estender por varias
# linhas.
# esta mensagem se estende
# por varias linhas
# do texto.

# %%
print ('este é um string.')
print (""" e este tambem é. """)
# Out:
# este é um string.
#  e este tambem é.

# %%
print(42000)
print (42,000)
print (41.000)
# Out:
# 42000
# 42 0
# 41.0

# %%
print (42, 17, 56, 11, 4, 35, 32)
print (3.4, "hello", 25)
# Out:
# 42 17 56 11 4 35 32
# 3.4 hello 25

# %%
print (3.14, int(3.24))
print (3.9999, int(3.9999))
print (3.0, int (-3.999))
print (-3.999, int(-3.999))

print ("2345", int("2345"))
print (17, int (17))
print (int("23"))
# Out:
# 3.14 3
# 3.9999 3
# 3.0 -3
# -3.999 -3
# 2345 2345
# 17 17
# 23

# %%
print(float("123.45"))
print(type(float("123.45")))
# Out:
# 123.45
# <class 'float'>

# %%
print(str(17))
print(str(123.45))
print(type(str(123.45)))
# Out:
# 17
# 123.45
# <class 'str'>

# %%
mensagem = "o que há velhinho?"
n = 17
pi = 3.14159

print (mensagem)
print (n)
print (pi)
# Out:
# o que há velhinho?
# 17
# 3.14159

# %%
mensagem = "o que há velhinho?"
n = 17
pi = 3.14159

print (type(mensagem))
print (type(n))
print (type(pi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
print(1+1)
print (len("ola"))
# Out:
# 2
# 3

# %%
y=3.14
x=len("ola")
print (x)
print (y)
# Out:
# 3
# 3.14

# %%
print(2+3)
print(2-3)
print(2*3)
print(2**3)
print(3**2)
# Out:
# 5
# -1
# 6
# 8
# 9

# %%
minutos = 645
horas = minutos/60
print(horas)
# Out:
# 10.75

# %%
print (7/4)
print (7//4)
munutos = 645
horas = minutos // 60
print(horas)
# Out:
# 1.75
# 1
# 10

# %%
quociente = 7//3 # divisao inteira
print(quociente)
resto = 7%3
print(resto)
# Out:
# 2
# 1

# %%
n = input("POR FAVOR, DIGITE O SEU NOME:  ")
print("OLA", n)
# Out:
# OLA PATRIANE

# %%
seconds_str = input("Por favor, entre com o numero de segundos que deseja converter: ")
total_segs = int(seconds_str)

horas = total_segs // 3600
segs_restantes = total_segs % 3600
minutos = segs_restantes // 60
segs_restantes_final = segs_restantes % 60

print("Hrs=", horas, "mins=", minutos, "segs=", segs_restantes_final)
# Out:
# Hrs= 2 mins= 46 segs= 40

# %%
16-2*5//3+1
# Out:
# 14

# %%
2**2**3*3
# Out:
# 768

# %%
bruce=5
print(bruce)
bruce=7
print(bruce)
# Out:
# 5
# 7

# %%
a=5
b=a
print(a,b)
a=3
print(a,b)
# Out:
# 5 5
# 3 5

# %%
x=15
y=x
x=22

# %%
x=6
print(x)
x=x+1
print(x)
# Out:
# 6
# 7

# %%
x=12
x=x-1
print(x)
# Out:
# 11

# %%
5**2
9*5
15/12
15//12
12//15
5%2
9%5
15%12
12%15
6%6
0%7
# Out:
# 0

# %%
hora_atual=14
horas_depois=51
alarme = (hora_atual + horas_depois) % 24
print(alarme)
# Out:
# 17

# %%
hora_atual = int(input("qual a hora atual?"))
horas_espera = int(input("quantas horas até o alarme?"))
alarme = (hora_atual + horas_espera) % 24
print("o alarme atual irá tocar às", alarme, "horas")
# Out:
# o alarme atual irá tocar às 6 horas

# %%
dia_semana = int(input("Qual o dia da semana que voce vai viajar? (0=dom, 1=seg, 2=ter, 3=qua, 4=qui, 5=sex, 6=sab): "))
dias_ferias = int(input("Quantos dias de férias?"))
dia_volta = (dia_semana + dias_ferias) % 7

dias = ["domingo", "segunda", "terca", "quarta", "quinta", "sexta", "sabado"]

print("voce voltará numa", dias[dia_volta])
# Out:
# voce voltará numa domingo

# %%
palavra1 = "só"
palavra2 = "trabalho"
palavra3 = "sem"
palavra4 = "diversao"
palavra5 = "faz"
palavra6 = "de"
palavra7 = "joao"
palavra8 = "um"
palavra9 = "chato"

print( palavra1, palavra2, palavra3, palavra4, palavra5, palavra6, palavra7, palavra8, palavra9)
# Out:
# só trabalho sem diversao faz de joao um chato

# %%
6*(1-2)
# Out:
# -6

# %%
p=10000
n=12
r=0.08
t=int(input("quantos anos?"))

a= p *(1+r/n)**(n*t)
print("valor final após", t, "anos: R$", round(a,2))
# Out:
# valor final após 1 anos: R$ 10830.0

# %%
import math

raio = float(input("digite o raio do círculo: "))
area = math.pi * raio ** 2
print("a area do circulo é: ", round(area,2))
# Out:
# a area do circulo é:  78.54

# %%
altura = float(input("digite a altura do retangulo: "))
largura = float(input("digite a largura do retangulo: "))
area = altura + largura

area = altura * largura

print("a area do retangulo é:", round(area, 2))
# Out:
# a area do retangulo é: 15.0

# %%
quilometros = float(input("quantos quilometros foram percorridos? "))
litros = float(input("quantos litros foram consumidos"))
consumo = quilometros / litros

print("o consumo do carro é:", round(consumo, 2), "km/1")
# Out:
# o consumo do carro é: 15.0 km/1

# %%
celsius = float(input("Digite a temperatura em celsius: " ))
fahrenheit = (celsius * 9/5) +32
print("a temperatura em fahrenheit é:", round(fahrenheit, 2), "F")
# Out:
# a temperatura em fahrenheit é: 32.0 F

# %%
fahrenheit = float(input("digite a temperatura em fahnrenheit: "))
celsius = (fahrenheit - 32) * 5/9
print ("a temperatura em celsius é:", round(celsius, 2), "c")
# Out:
# a temperatura em celsius é: 18.89 c
